# %% [markdown]
# # Project Name:- HR Analytics Project- Understanding the Attrition in HR

# %% [markdown]
# # Project Description
# Every year a lot of companies hire a number of employees. The companies invest time and money in training those employees, not just this but there are training programs within the companies for their existing employees as well. The aim of these programs is to increase the effectiveness of their employees. But where HR Analytics fit in this? and is it just about improving the performance of employees?
# HR Analytics
# Human resource analytics (HR analytics) is an area in the field of analytics that refers to applying analytic processes to the human resource department of an organization in the hope of improving employee performance and therefore getting a better return on investment. HR analytics does not just deal with gathering data on employee efficiency. Instead, it aims to provide insight into each process by gathering data and then using it to make relevant decisions about how to improve these processes.
# Attrition in HR
# Attrition in human resources refers to the gradual loss of employees overtime. In general, relatively high attrition is problematic for companies. HR professionals often assume a leadership role in designing company compensation programs, work culture, and motivation systems that help the organization retain top employees.
# How does Attrition affect companies? and how does HR Analytics help in analyzing attrition? We will discuss the first question here and for the second question, we will write the code and try to understand the process step by step.
# Attrition affecting Companies
# A major problem in high employee attrition is its cost to an organization. Job postings, hiring processes, paperwork, and new hire training are some of the common expenses of losing employees and replacing them. Additionally, regular employee turnover prohibits your organization from increasing its collective knowledge base and experience over time. This is especially concerning if your business is customer-facing, as customers often prefer to interact with familiar people. Errors and issues are more likely if you constantly have new workers.

# %% [markdown]
# # Problem Definition:
#
# The project is titled "HR Analytics Project: Understanding the Attrition in HR." The focus is on how HR analytics can be used to understand and manage employee attrition. The problem is set in the context of companies investing in employee training and the challenges posed by employee attrition. The goal is to analyze how attrition affects companies and how HR analytics can help mitigate this issue.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"E:/ibm-hr-analytics-employee-attrition-performance/WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# * NOTE:-
#
# 1. AGE = consists Numerical Value
# 2. ATTRITION = consists Employee leaving the company (1=no, 2=yes)
# 3. BUSINESS TRAVEL = consists	(1=No Travel, 2=Travel Frequently, 3=Tavel Rarely)
# 4. DAILY RATE = consists Numerical Value - Salary Level
# 5. DEPARTMENT = consists	(1=HR, 2=R&D, 3=Sales)
# 6. DISTANCE FROM HOME = consists	Numerical Value - THE DISTANCE FROM WORK TO HOME
# 7. EDUCATION = consists	Numerical Value
# 8. EDUCATION FIELD	= consists	(1=HR, 2=LIFE SCIENCES, 3=MARKETING, 4=MEDICAL SCIENCES, 5=OTHERS, 6= TEHCNICAL)
# 9. EMPLOYEE COUNT = consists	Numerical Value
# 10. EMPLOYEE NUMBER = consists	Numerical Value - EMPLOYEE ID
# 11. ENVIROMENT SATISFACTION	= consists	Numerical Value - SATISFACTION WITH THE ENVIROMENT
# 12. GENDER	= consists	(1=FEMALE, 2=MALE)
# 13. HOURLY RATE	= consists	Numerical Value - HOURLY SALARY
# 14. JOB INVOLVEMENT= consists	Numerical Value - JOB INVOLVEMENT
# 15. JOB LEVEL	= consists	Numerical Value - LEVEL OF JOB
# 16. JOB ROLE= consists(1=HC REP, 2=HR, 3=LAB TECHNICIAN, 4=MANAGER, 5= Manufacturing Director, 6= REASEARCH DIRECTOR, 7= RESEARCH SCIENTIST, 8=SALES EXECUTIEVE, 9= SALES REPRESENTATIVE)
# 17. JOB SATISFACTION= consists	Numerical Value - SATISFACTION WITH THE JOB
# 18. MARITAL STATUS = consists	(1=DIVORCED, 2=MARRIED, 3=SINGLE)
# 19. MONTHLY INCOME = consists	Numerical Value - MONTHLY SALARY
# 20. MONTHY RATE = consists	Numerical Value - MONTHY RATE
# 21. NUMCOMPANIES WORKED	= consists	Numerical Value - NO. OF COMPANIES WORKED AT
# 22. OVER 18	= consists	(1=YES, 2=NO)
# 23. OVERTIME=consists	(1=NO, 2=YES)
# 24. PERCENT SALARY HIKE = consists	Numerical Value - PERCENTAGE INCREASE IN SALARY
# 25. PERFORMANCE RATING = consists	Numerical Value - ERFORMANCE RATING
# 26. RELATIONS SATISFACTION	= consists	Numerical Value - RELATIONS SATISFACTION
# 27. STANDARD HOURS	= consists	Numerical Value - STANDARD HOURS
# 28. STOCK OPTIONS LEVEL	= consists	Numerical Value - STOCK OPTIONS
# 29. TOTAL WORKING YEARS	= consists	Numerical Value - TOTAL YEARS WORKED
# 30. TRAINING TIMES LAST YEAR= consists	Numerical Value - HOURS SPENT TRAINING
# 31. WORK LIFE BALANCE = consists	Numerical Value - TIME SPENT BEWTWEEN WORK AND OUTSIDE
# 32. YEARS AT COMPANY = consists	Numerical Value - TOTAL NUMBER OF YEARS AT THE COMPNAY
# 33. YEARS IN CURRENT ROLE = consists	Numerical Value -YEARS IN CURRENT ROLE
# 34. YEARS SINCE LAST PROMOTION = consists	Numerical Value - LAST PROMOTION
# 35. YEARS WITH CURRENT MANAGER = consists	Numerical Value - YEARS SPENT WITH CURRENT MANAGER

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   object
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(26), object(9)
# memory usage: 402.1+ KB

# %%
print('Number of Rows:',df.shape[0])
print('Number of Columns:',df.shape[1])
# Out:
# Number of Rows: 1470
# Number of Columns: 35

# %% [markdown]
# # EDA

# %%
#checking null values
sns.heatmap(df.isnull().sum().to_frame())
print('\n',df.isnull().sum())
# Out:
#  Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %% [markdown]
# # Comment:-
# There is no value in dataset

# %% [markdown]
# # Extracting Categorical Columns

# %%
cat = (df.dtypes == 'object')
print("Categorical variables:",len(list(cat[cat].index)))
# Out:
# Categorical variables: 9

# %%
categorical_columns = df.select_dtypes(include=['object']).columns

# Displaying the result
print("Categorical Columns:",categorical_columns)
# Out:
# Categorical Columns: Index(['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
#        'JobRole', 'MaritalStatus', 'Over18', 'OverTime'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# # Encoding Columns into Numerical Columns

# %%
#count of  categorical value
print(df['Attrition'].value_counts())
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
# encoding attrition columns.
df= df.replace({"Attrition":{"No":0, "Yes":1 }})

# %%
#count of  categorical value
print(df['BusinessTravel'].value_counts())
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %%
# encoding Bussiness Travel columns.
df= df.replace({"BusinessTravel":{"Non-Travel":1, "Travel_Frequently":2,"Travel_Rarely":3 }})

# %%
# count of categorical value.
print(df['Department'].value_counts())
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
# encoding Department column.
df= df.replace({"Department":{"Human Resources":1, "Research & Development":2, "Sales":3 }})

# %%
# encoding Educationfield columns.
print(df['EducationField'].value_counts())
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
#encoding EducationFiield columns.
df= df.replace({"EducationField":{"Human Resources":1, "Life Sciences":2, 
                                  "Marketing":3, "Medical":4,
                                  "Other":5, "Technical Degree":6 }})

# %%
# value count of gender column
print(df['Gender'].value_counts())
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %%
#encoding Gender column
df=df.replace({'Gender':{'Male':1,'Female':0}})

# %%
# value count of JobRole 
print(df['JobRole'].value_counts())
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %%
#encoding of Jobrole column
df=df.replace({'JobRole':{'Sales Executive':1,'Research Scientist':2,'Laboratory Technician':3,'Manufacturing Director':4,
                          'Healthcare Representative':5,'Manager':6,'Sales Representative':7,'Research Director':8,
                         'Human Resources':9}})

# %%
#value count of MaritalStatus column
print(df['MaritalStatus'].value_counts())
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %%
#encodeing of MaritalStatus
df=df.replace({'MaritalStatus':{'Married':1,'Single':2,'Divorced':3}})

# %%
#value count of Overtime  column
print(df['OverTime'].value_counts())
# Out:
# No     1054
# Yes     416
# Name: OverTime, dtype: int64

# %%
#encoding of overtime column
df=df.replace({'OverTime':{'No':0,'Yes':1}})

# %%
#value count of Ovetime column
print(df['Over18'].value_counts())
# Out:
# Y    1470
# Name: Over18, dtype: int64

# %%
df=df.replace({'Over18':{'Y':1}})

# %%
#checking encoded value
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int64
#  2   BusinessTravel            1470 non-null   int64
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   int64
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   int64
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   int64
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   int64
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   int64
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   int64
#  22  OverTime                  1470 non-null   int64
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(35)
# memory usage: 402.1 KB

# %%
df.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               3       1102           3                 1
# 1   49          0               2        279           2                 8
# 2   37          1               3       1373           2                 2
# 3   33          0               2       1392           2                 3
# 4   27          0               3        591           2                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2               2              1               1  ...
# 1          1               2              1               2  ...
# 2          2               5              1               4  ...
# 3          4               2              1               5  ...
# 4          1               4              1               7  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                         1             80                 0
# 1                         4             80                 1
# 2                         2             80                 0
# 3                         3             80                 0
# 4                         4             80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0                1               6
# 1                 10                      3                3              10
# 2                  7                      3                3               0
# 3                  8                      3                3               8
# 4                  6                      3                3               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                   4                        0                     5
# 1                   7                        1                     7
# 2                   0                        0                     0
# 3                   7                        3                     0
# 4                   2                        2                     2
#
# [5 rows x 35 columns]

# %%
df.drop(columns=['StandardHours','EmployeeCount','Over18'],axis=1,inplace=True)

# %% [markdown]
# # Comment -
# we can drop 'Employee count', 'Over18' and 'standard hour'. because it contain single data all over the columns

# %%
print('columns left After Droping unwanted columns:',df.shape[1])
# Out:
# columns left After Droping unwanted columns: 32

# %% [markdown]
# # Concluding Remarks of EDA:
#
# There's a mention of an EDA section where the comment highlights that "the number of Nulls is zero," indicating that the dataset used is clean with no missing values.

# %% [markdown]
# # Statistical Analysis

# %%
df.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# Attrition                 1470.0      0.161224     0.367863     0.0     0.00
# BusinessTravel            1470.0      2.607483     0.665455     1.0     2.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# Department                1470.0      2.260544     0.527792     1.0     2.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EducationField            1470.0      3.247619     1.331369     1.0     2.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# Gender                    1470.0      0.600000     0.490065     0.0     0.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobRole                   1470.0      3.553061     2.323902     1.0     2.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# MaritalStatus             1470.0      1.764626     0.790757     1.0     1.00
# MonthlyIncome             1470.0   6502.931293  4707.956783  1009.0  2911.00
# MonthlyRate               1470.0  14313.103401  7117.786044  2094.0  8047.00
# NumCompaniesWorked        1470.0      2.693197     2.498009     0.0     1.00
# OverTime                  1470.0      0.282993     0.450606     0.0     0.00
# PercentSalaryHike         1470.0     15.209524     3.659938    11.0    12.00
# PerformanceRating         1470.0      3.153741     0.360824     3.0     3.00
# RelationshipSatisfaction  1470.0      2.712245     1.081209     1.0     2.00
# StockOptionLevel          1470.0      0.793878     0.852077     0.0     0.00
# TotalWorkingYears         1470.0     11.279592     7.780782     0.0     6.00
# TrainingTimesLastYear     1470.0      2.799320     1.289271     0.0     2.00
# WorkLifeBalance           1470.0      2.761224     0.706476     1.0     2.00
# YearsAtCompany            1470.0      7.008163     6.126525     0.0     3.00
# YearsInCurrentRole        1470.0      4.229252     3.623137     0.0     2.00
# YearsSinceLastPromotion   1470.0      2.187755     3.222430     0.0     0.00
# YearsWithCurrManager      1470.0      4.123129     3.568136     0.0     2.00
#
#                               50%       75%      max
# Age                          36.0     43.00     60.0
# Attrition                     0.0      0.00      1.0
# BusinessTravel                3.0      3.00      3.0
# DailyRate                   802.0   1157.00   1499.0
# Department                    2.0      3.00      3.0
# DistanceFromHome              7.0     14.00     29.0
# Education                     3.0      4.00      5.0
# EducationField                3.0      4.00      6.0
# EmployeeNumber             1020.5   1555.75   2068.0
# EnvironmentSatisfaction       3.0      4.00      4.0
# Gender                        1.0      1.00      1.0
# HourlyRate                   66.0     83.75    100.0
# JobInvolvement                3.0      3.00      4.0
# JobLevel                      2.0      3.00      5.0
# JobRole                       3.0      5.00      9.0
# JobSatisfaction               3.0      4.00      4.0
# MaritalStatus                 2.0      2.00      3.0
# MonthlyIncome              4919.0   8379.00  19999.0
# MonthlyRate               14235.5  20461.50  26999.0
# NumCompaniesWorked            2.0      4.00      9.0
# OverTime                      0.0      1.00      1.0
# PercentSalaryHike            14.0     18.00     25.0
# PerformanceRating             3.0      3.00      4.0
# RelationshipSatisfaction      3.0      4.00      4.0
# StockOptionLevel              1.0      1.00      3.0
# TotalWorkingYears            10.0     15.00     40.0
# TrainingTimesLastYear         3.0      3.00      6.0
# WorkLifeBalance               3.0      3.00      4.0
# YearsAtCompany                5.0      9.00     40.0
# YearsInCurrentRole            3.0      7.00     18.0
# YearsSinceLastPromotion       1.0      3.00     15.0
# YearsWithCurrManager          3.0      7.00     17.0

# %%
plt.figure(figsize=(14,10))
sns.heatmap(df.describe().T,linewidth=0.3,fmt='0.3f' ,annot=True,cmap='gist_heat')
# Out:
# <Axes: >

# %% [markdown]
# # Comment:-
#    In this statistical analysis there is alot potential that this dataset have outlier

# %% [markdown]
# # Outlier Detection

# %%
plt.figure(figsize=(30,60))
index=1
for column in df:
    if index <=32:
        ax = plt.subplot(11,3,index)
        sns.boxplot(df[column], palette='pastel')
        plt.xlabel(column,fontsize=20)
    index+=1
plt.show()

# %% [markdown]
# # Comment-
# [Attrition,monthlyIncome,numcompaniesworked,performancerating,
#          stockoptionlevel,totalworkingyears,trainingtimelastyear,yearsatcompany,
#          yearsincurrentrole,yearssincelastpromotion,yearwithcurrmanager]
# * These column have outliers.

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# # Removing Outliers

# %%
from scipy.stats import zscore

columns_to_remove_outliers = ['Attrition','MonthlyIncome','NumCompaniesWorked',
'PerformanceRating','StockOptionLevel','TotalWorkingYears', 'TrainingTimesLastYear','YearsAtCompany', 'YearsInCurrentRole',
       'YearsSinceLastPromotion', 'YearsWithCurrManager']

z_scores = df[columns_to_remove_outliers].apply(zscore)
threshold = 3


df1 = df[(z_scores.abs() < threshold).all(axis=1)]

# %%
print('Shape of dataset after removing outliers :', df.shape)
# Out:
# Shape of dataset after removing outliers : (1470, 32)

# %%
# data Loss
print('Percentage Data Loss :',((1470-1470)/1470)*100,'%')
# Out:
# Percentage Data Loss : 0.0 %

# %% [markdown]
# # Comment :-
# Our assumption is wrong there is no Outliers

# %% [markdown]
# # Skewness

# %%
plt.figure(figsize=(30,60))
plotnumber=1
for column in df:
    if plotnumber <=32:
        ax = plt.subplot(11,3,plotnumber)
        sns.distplot(df[column], color='r',hist=False,kde_kws={"shade": True})
        plt.xlabel(column,fontsize=30)
    plotnumber+=1
plt.show()

# %%
skewed_column=df.skew()
skewed_column
# Out:
# Age                         0.413286
# Attrition                   1.844366
# BusinessTravel             -1.439006
# DailyRate                  -0.003519
# Department                  0.172231
# DistanceFromHome            0.958118
# Education                  -0.289681
# EducationField              0.550371
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# Gender                     -0.408665
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobRole                     0.770149
# JobSatisfaction            -0.329672
# MaritalStatus               0.443615
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# OverTime                    0.964489
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StockOptionLevel            0.968980
# TotalWorkingYears           1.117172
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# YearsAtCompany              1.764529
# YearsInCurrentRole          0.917363
# YearsSinceLastPromotion     1.984290
# YearsWithCurrManager        0.833451
# dtype: float64

# %% [markdown]
# # Comment:-
# Optimal range for skewness is -0.5 to 0.5. And these columns  are right skewed ['Attrition', 'BusinessTravel', 'DistanceFromHome', 'JobLevel', 'JobRole', 'MonthlyIncome','NumCompaniesWorked','OverTime','PercentSalaryHike','PerformanceRating','StockOptionLevel',
#                'TotalWorkingYears','TrainingTimesLastYear','WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#                  'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
#Checking multicollinearity using Varience-inflation-factor (VIF)

from statsmodels.stats.outliers_influence import variance_inflation_factor

vif= pd.DataFrame()
vif['VIF'] = [variance_inflation_factor(df.values,i) for i in range(df.shape[1])]
vif['Features'] = df.columns
vif
# Out:
#            VIF                  Features
# 0    33.639621                       Age
# 1     1.497446                 Attrition
# 2    15.570642            BusinessTravel
# 3     4.998129                 DailyRate
# 4    23.819678                Department
# 5     2.341961          DistanceFromHome
# 6     9.477478                 Education
# 7     6.928045            EducationField
# 8     3.933359            EmployeeNumber
# 9     7.253293   EnvironmentSatisfaction
# 10    2.522436                    Gender
# 11   11.307949                HourlyRate
# 12   15.420383            JobInvolvement
# 13   52.266936                  JobLevel
# 14    5.026446                   JobRole
# 15    7.081908           JobSatisfaction
# 16    6.013349             MaritalStatus
# 17   33.808329             MonthlyIncome
# 18    5.047147               MonthlyRate
# 19    2.772794        NumCompaniesWorked
# 20    1.549943                  OverTime
# 21   43.101392         PercentSalaryHike
# 22  134.475704         PerformanceRating
# 23    7.342590  RelationshipSatisfaction
# 24    1.968094          StockOptionLevel
# 25   14.724473         TotalWorkingYears
# 26    5.776917     TrainingTimesLastYear
# 27   15.936982           WorkLifeBalance
# 28   10.616413            YearsAtCompany
# 29    6.484416        YearsInCurrentRole
# 30    2.472346   YearsSinceLastPromotion
# 31    6.517976      YearsWithCurrManager

# %% [markdown]
# # Comment -
# Here, we can see that column (EmployeeNumber,Gender,OverTime,StockOptionLevel,YearsSinceLastPromotion) have very less correlation to target variable. So we can drop it.

# %%
X=df[['Age', 'BusinessTravel', 'DailyRate', 'Department','DistanceFromHome', 'Education', 'EducationField', 'EnvironmentSatisfaction', 'HourlyRate','JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction','MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating','RelationshipSatisfaction','TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance','YearsAtCompany', 'YearsInCurrentRole','YearsWithCurrManager']]

# %%
#Target variable
y= df.Attrition
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1470, dtype: int64

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split
for i in range(0,200):
    X_train,X_test,y_train,y_test = train_test_split(X,y, test_size= .2, random_state=i)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# Logistic Regression model
lgr = LogisticRegression()
lgr.fit(X_train, y_train)

pred = lgr.predict(X_test)

r = accuracy_score(y_test, pred)

print('accuracy Score for Logistic Regression test data is:', r*100)
# Out:
# accuracy Score for Logistic Regression test data is: 84.6938775510204

# %% [markdown]
# # Raandom Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state = 0)
rf.fit(X_train, y_train)

y_pred_train = rf.predict(X_train)
y_pred_test = rf.predict(X_test)
print('Accuracy score for test data using Random Forest :', accuracy_score(y_test,y_pred_test)*100)
# Out:
# Accuracy score for test data using Random Forest : 84.35374149659864

# %% [markdown]
# # Decsion Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dtr.fit(X_train, y_train)

pred2 = dtr.predict(X_test)

r2 = accuracy_score(y_test, pred2)

print("R-squared:", r2*100)
# Out:
# R-squared: 79.25170068027211

# %% [markdown]
# # Prediction Through Logistic Regression

# %%
prediction_=pd.DataFrame({'predicted values':pred,'actual values':y_test})
prediction_
# Out:
#       predicted values  actual values
# 156                  0              0
# 809                  0              0
# 1083                 0              1
# 771                  0              0
# 404                  0              0
# ...                ...            ...
# 1379                 0              1
# 920                  0              0
# 1082                 0              0
# 1231                 0              0
# 876                  0              0
#
# [294 rows x 2 columns]

# %% [markdown]
# # Best Model

# %%
import joblib

model = LogisticRegression(fit_intercept=False,random_state=None, max_iter=10)
model.fit(X_train, y_train)

joblib.dump(model, 'avocado_model.joblib')
# Out:
# ['avocado_model.joblib']

# %% [markdown]
# # Conclusion

# %% [markdown]
# # Logistic Regression was selected as the best-performing model for predicting employee attrition.
# The final Logistic Regression model was saved for future use.
#
# The project successfully built models to predict employee attrition using HR data. Logistic Regression was identified as the best model for this task, providing a reliable method to analyze factors contributing to employee turnover. The insights gained can help companies take proactive measures to reduce attrition and retain valuable employees.
