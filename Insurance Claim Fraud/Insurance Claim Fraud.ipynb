# %% [markdown]
# # Project Name:- Insurance Claim Fraud Detection

# %% [markdown]
# # Project Description:-
# Insurance fraud is a huge problem in the industry. It's difficult to identify fraud claims. Machine Learning is in a unique position to help the Auto Insurance industry with this problem.
# In this project, you are provided a dataset which has the details of the insurance policy along with the customer details. It also has the details of the accident on the basis of which the claims have been made.
# In this example, you will be working with some auto insurance data to demonstrate how you can create a predictive model that predicts if an insurance claim is fraudulent or not.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv("E:\Insurance Claim Fraud\Automobile_insurance_fraud.csv")

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 0       466132  ...                     YES              71610         6510
# 1       468176  ...                       ?               5070          780
# 2       430632  ...                      NO              34650         7700
# 3       608117  ...                      NO              63400         6340
# 4       610706  ...                      NO               6500         1300
#
#   property_claim vehicle_claim  auto_make  auto_model auto_year  \
# 0          13020         52080       Saab         92x      2004
# 1            780          3510   Mercedes        E400      2007
# 2           3850         23100      Dodge         RAM      2007
# 3           6340         50720  Chevrolet       Tahoe      2014
# 4            650          4550     Accura         RSX      2009
#
#   fraud_reported _c39
# 0              Y  NaN
# 1              Y  NaN
# 2              N  NaN
# 3              Y  NaN
# 4              N  NaN
#
# [5 rows x 40 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
#  13  insured_hobbies              1000 non-null   object
#  14  insured_relationship         1000 non-null   object
#  15  capital-gains                1000 non-null   int64
#  16  capital-loss                 1000 non-null   int64
#  17  incident_date                1000 non-null   object
#  18  incident_type                1000 non-null   object
#  19  collision_type               1000 non-null   object
#  20  incident_severity            1000 non-null   object
#  21  authorities_contacted        1000 non-null   object
#  22  incident_state               1000 non-null   object
#  23  incident_city                1000 non-null   object
#  24  incident_location            1000 non-null   object
#  25  incident_hour_of_the_day     1000 non-null   int64
#  26  number_of_vehicles_involved  1000 non-null   int64
#  27  property_damage              1000 non-null   object
#  28  bodily_injuries              1000 non-null   int64
#  29  witnesses                    1000 non-null   int64
#  30  police_report_available      1000 non-null   object
#  31  total_claim_amount           1000 non-null   int64
#  32  injury_claim                 1000 non-null   int64
#  33  property_claim               1000 non-null   int64
#  34  vehicle_claim                1000 non-null   int64
#  35  auto_make                    1000 non-null   object
#  36  auto_model                   1000 non-null   object
#  37  auto_year                    1000 non-null   int64
#  38  fraud_reported               1000 non-null   object
#  39  _c39                         0 non-null      float64
# dtypes: float64(2), int64(17), object(21)
# memory usage: 312.6+ KB

# %%
print('Number Of Rows :', df.shape[0])
print('Number Of Columns :',df.shape[1])
# Out:
# Number Of Rows : 1000
# Number Of Columns : 40

# %%
df['policy_bind_date']= pd.to_datetime(df['policy_bind_date'])
df['policy_year'] =df['policy_bind_date'].dt.year

# %%
df.drop(['policy_bind_date'],axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_state                 1000 non-null   object
#  4   policy_csl                   1000 non-null   object
#  5   policy_deductable            1000 non-null   int64
#  6   policy_annual_premium        1000 non-null   float64
#  7   umbrella_limit               1000 non-null   int64
#  8   insured_zip                  1000 non-null   int64
#  9   insured_sex                  1000 non-null   object
#  10  insured_education_level      1000 non-null   object
#  11  insured_occupation           1000 non-null   object
#  12  insured_hobbies              1000 non-null   object
#  13  insured_relationship         1000 non-null   object
#  14  capital-gains                1000 non-null   int64
#  15  capital-loss                 1000 non-null   int64
#  16  incident_date                1000 non-null   object
#  17  incident_type                1000 non-null   object
#  18  collision_type               1000 non-null   object
#  19  incident_severity            1000 non-null   object
#  20  authorities_contacted        1000 non-null   object
#  21  incident_state               1000 non-null   object
#  22  incident_city                1000 non-null   object
#  23  incident_location            1000 non-null   object
#  24  incident_hour_of_the_day     1000 non-null   int64
#  25  number_of_vehicles_involved  1000 non-null   int64
#  26  property_damage              1000 non-null   object
#  27  bodily_injuries              1000 non-null   int64
#  28  witnesses                    1000 non-null   int64
#  29  police_report_available      1000 non-null   object
#  30  total_claim_amount           1000 non-null   int64
#  31  injury_claim                 1000 non-null   int64
#  32  property_claim               1000 non-null   int64
#  33  vehicle_claim                1000 non-null   int64
#  34  auto_make                    1000 non-null   object
#  35  auto_model                   1000 non-null   object
#  36  auto_year                    1000 non-null   int64
#  37  fraud_reported               1000 non-null   object
#  38  _c39                         0 non-null      float64
#  39  policy_year                  1000 non-null   int64
# dtypes: float64(2), int64(18), object(20)
# memory usage: 312.6+ KB

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_state',
#        'policy_csl', 'policy_deductable', 'policy_annual_premium',
#        'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported', '_c39', 'policy_year'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted             0
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# number_of_vehicles_involved       0
# property_damage                   0
# bodily_injuries                   0
# witnesses                         0
# police_report_available           0
# total_claim_amount                0
# injury_claim                      0
# property_claim                    0
# vehicle_claim                     0
# auto_make                         0
# auto_model                        0
# auto_year                         0
# fraud_reported                    0
# _c39                           1000
# policy_year                       0
# dtype: int64

# %%
df.isin(['?']).sum().any()
# Out:
# True

# %%
df.replace('?',np.nan,inplace=True)

# %%
sns.heatmap(df.isna())
df.isna().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                  178
# incident_severity                 0
# authorities_contacted             0
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# number_of_vehicles_involved       0
# property_damage                 360
# bodily_injuries                   0
# witnesses                         0
# police_report_available         343
# total_claim_amount                0
# injury_claim                      0
# property_claim                    0
# vehicle_claim                     0
# auto_make                         0
# auto_model                        0
# auto_year                         0
# fraud_reported                    0
# _c39                           1000
# policy_year                       0
# dtype: int64

# %%
df.drop(['_c39'], axis=1, inplace=True)

# %%
# Removing Null Values
# Replacing Null with mode of the column because it contain categorical data

df['collision_type'].fillna(value=df['collision_type'].mode()[0], inplace= True)
df['property_damage'].fillna(value=df['property_damage'].mode()[0], inplace= True)
df['police_report_available'].fillna(value=df['police_report_available'].mode()[0], inplace= True)

# %%
df.isna().sum().any()
# Out:
# False

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # Univariate Analysis

# %%
# plotting histogrm for target variables
plt.figure(figsize=(4,4),)
sns.histplot(df['fraud_reported'],color='g')
plt.title('Fraud Reported')
plt.show()

# %%
# plotting histogram for targete variables
plt.figure(figsize=(4,4))
sns.barplot(df['auto_year'],color='r')
plt.show()

# %%
plt.figure(figsize=(4,4))
plt.subplot(1,2,1)
sns.barplot(df['auto_year'],color='b')
plt.subplot(1,2,2)
sns.barplot(df['policy_number'],color='r')
plt.show()

# %%
df.drop(['auto_year', 'policy_number'], axis=1, inplace=True)

# %%
plt.figure(figsize=(4,4))
sns.histplot(df['number_of_vehicles_involved'])
plt.title('Number of Vehicle')
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.histplot(df['police_report_available'])
plt.title('Police Report')
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.histplot(df['property_damage'])
plt.title('property Damage ')
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.histplot(df['total_claim_amount'])
plt.title(' total claim amount ')
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.subplot(1,2,1)
sns.histplot(df['capital-gains'],kde=True,color='r')
plt.xticks(fontsize=10,rotation=90)
plt.subplot(1,2,2)
sns.histplot(df['capital-loss'],kde=True,color='m')
plt.xticks(fontsize=10,rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,25))

categories =['months_as_customer', 'age', 
       'policy_state', 'policy_csl', 'policy_deductable',
       'policy_annual_premium', 'insured_zip', 'insured_sex',
       'insured_education_level', 'insured_occupation', 'insured_hobbies',
       'insured_relationship','incident_date', 'incident_type', 'collision_type',
       'incident_severity','authorities_contacted', 'incident_state', 'incident_city',
        'incident_hour_of_the_day','bodily_injuries','witnesses', 
       'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make','policy_year']

for i, category in enumerate(categories, 1):
    plt.subplot(7, 4, i)
    sns.countplot(data=df, x=category)
    plt.xlabel(category, fontsize=25)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
# Analysis with Target variable.
plt.figure(figsize=(12,6))
sns.countplot(data=df, x='policy_year', hue='fraud_reported')
plt.xticks(fontsize=10,rotation=90)
plt.show()

# %%
# Analysis with Target variable.
plt.figure(figsize=(12,6))
sns.countplot(data=df, x='policy_year', hue='bodily_injuries')
plt.xticks(fontsize=10,rotation=90)
plt.show()

# %%
# Analysis with Target variable.
plt.figure(figsize=(8,6))
sns.countplot(data=df, x='incident_type', hue='fraud_reported')
plt.xticks(fontsize=10,rotation=90)
plt.show()

# %% [markdown]
# # Comment:-
# Fraud reported is very high in single and multi vehicle colision and very less in vehicle theft and parked car.

# %% [markdown]
# # Encoding Categorical Value to Numeric

# %%
categorical_columns = df.select_dtypes(include=['object']).columns.tolist()

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

for col in categorical_columns:
    df[col] = label_encoder.fit_transform(df[col])

# %% [markdown]
# # Statistical Analysis

# %%
df.describe().T
# Out:
#                               count          mean           std         min  \
# months_as_customer           1000.0  2.039540e+02  1.151132e+02        0.00
# age                          1000.0  3.894800e+01  9.140287e+00       19.00
# policy_state                 1000.0  1.014000e+00  8.309600e-01        0.00
# policy_csl                   1000.0  9.510000e-01  8.045162e-01        0.00
# policy_deductable            1000.0  1.136000e+03  6.118647e+02      500.00
# policy_annual_premium        1000.0  1.256406e+03  2.441674e+02      433.33
# umbrella_limit               1000.0  1.101000e+06  2.297407e+06 -1000000.00
# insured_zip                  1000.0  5.012145e+05  7.170161e+04   430104.00
# insured_sex                  1000.0  4.630000e-01  4.988786e-01        0.00
# insured_education_level      1000.0  2.966000e+00  1.948497e+00        0.00
# insured_occupation           1000.0  6.653000e+00  4.019048e+00        0.00
# insured_hobbies              1000.0  9.731000e+00  5.674049e+00        0.00
# insured_relationship         1000.0  2.416000e+00  1.681003e+00        0.00
# capital-gains                1000.0  2.512610e+04  2.787219e+04        0.00
# capital-loss                 1000.0 -2.679370e+04  2.810410e+04  -111100.00
# incident_date                1000.0  2.937600e+01  1.724987e+01        0.00
# incident_type                1000.0  1.172000e+00  1.081474e+00        0.00
# collision_type               1000.0  1.022000e+00  7.280426e-01        0.00
# incident_severity            1000.0  1.184000e+00  9.396952e-01        0.00
# authorities_contacted        1000.0  2.167000e+00  1.532142e+00        0.00
# incident_state               1000.0  3.242000e+00  2.155942e+00        0.00
# incident_city                1000.0  2.966000e+00  2.044266e+00        0.00
# incident_location            1000.0  4.995000e+02  2.888194e+02        0.00
# incident_hour_of_the_day     1000.0  1.164400e+01  6.951373e+00        0.00
# number_of_vehicles_involved  1000.0  1.839000e+00  1.018880e+00        1.00
# property_damage              1000.0  3.020000e-01  4.593550e-01        0.00
# bodily_injuries              1000.0  9.920000e-01  8.201272e-01        0.00
# witnesses                    1000.0  1.487000e+00  1.111335e+00        0.00
# police_report_available      1000.0  3.140000e-01  4.643486e-01        0.00
# total_claim_amount           1000.0  5.276194e+04  2.640153e+04      100.00
# injury_claim                 1000.0  7.433420e+03  4.880952e+03        0.00
# property_claim               1000.0  7.399570e+03  4.824726e+03        0.00
# vehicle_claim                1000.0  3.792895e+04  1.888625e+04       70.00
# auto_make                    1000.0  6.546000e+00  4.034869e+00        0.00
# auto_model                   1000.0  1.931800e+01  1.113611e+01        0.00
# fraud_reported               1000.0  2.470000e-01  4.314825e-01        0.00
# policy_year                  1000.0  2.001604e+03  7.360391e+00     1990.00
#
#                                      25%       50%         75%          max
# months_as_customer              115.7500     199.5     276.250       479.00
# age                              32.0000      38.0      44.000        64.00
# policy_state                      0.0000       1.0       2.000         2.00
# policy_csl                        0.0000       1.0       2.000         2.00
# policy_deductable               500.0000    1000.0    2000.000      2000.00
# policy_annual_premium          1089.6075    1257.2    1415.695      2047.59
# umbrella_limit                    0.0000       0.0       0.000  10000000.00
# insured_zip                  448404.5000  466445.5  603251.000    620962.00
# insured_sex                       0.0000       0.0       1.000         1.00
# insured_education_level           1.0000       3.0       5.000         6.00
# insured_occupation                3.0000       7.0      10.000        13.00
# insured_hobbies                   5.0000      10.0      15.000        19.00
# insured_relationship              1.0000       2.0       4.000         5.00
# capital-gains                     0.0000       0.0   51025.000    100500.00
# capital-loss                 -51500.0000  -23250.0       0.000         0.00
# incident_date                    14.7500      29.5      44.000        59.00
# incident_type                     0.0000       1.0       2.000         3.00
# collision_type                    0.0000       1.0       2.000         2.00
# incident_severity                 0.0000       1.0       2.000         3.00
# authorities_contacted             1.0000       2.0       4.000         4.00
# incident_state                    1.0000       4.0       5.000         6.00
# incident_city                     1.0000       3.0       5.000         6.00
# incident_location               249.7500     499.5     749.250       999.00
# incident_hour_of_the_day          6.0000      12.0      17.000        23.00
# number_of_vehicles_involved       1.0000       1.0       3.000         4.00
# property_damage                   0.0000       0.0       1.000         1.00
# bodily_injuries                   0.0000       1.0       2.000         2.00
# witnesses                         1.0000       1.0       2.000         3.00
# police_report_available           0.0000       0.0       1.000         1.00
# total_claim_amount            41812.5000   58055.0   70592.500    114920.00
# injury_claim                   4295.0000    6775.0   11305.000     21450.00
# property_claim                 4445.0000    6750.0   10885.000     23670.00
# vehicle_claim                 30292.5000   42100.0   50822.500     79560.00
# auto_make                         3.0000       7.0      10.000        13.00
# auto_model                       10.0000      20.0      29.000        38.00
# fraud_reported                    0.0000       0.0       0.000         1.00
# policy_year                    1995.0000    2002.0    2008.000      2015.00

# %% [markdown]
# # Correlation Between Dataset

# %%
plt.figure(figsize=(35,30))
sns.heatmap(df.corr(),annot=True,linewidths=0.5,linecolor='black',fmt=' .2f' )
# Out:
# <Axes: >

# %% [markdown]
# # comment :-
# 1) incident_severity is Negatively correlated to target variable. So, it need to drop it. 2) number_of_vehicles_involved is also negatively correlated to Dataset

# %%
df.drop(['incident_severity'],axis=1,inplace=True)

# %%
df.drop(['number_of_vehicles_involved'],axis=1,inplace=True)

# %% [markdown]
# # Outlier Detection

# %%
columns=['months_as_customer', 'age', 'policy_state', 'policy_csl',
       'policy_deductable', 'policy_annual_premium', 'umbrella_limit',
       'insured_zip', 'insured_sex', 'insured_education_level',
       'insured_occupation', 'insured_hobbies', 'insured_relationship',
       'capital-gains', 'capital-loss', 'incident_date', 'incident_type',
       'collision_type', 'authorities_contacted',
       'incident_state', 'incident_city', 'incident_location',
       'property_damage', 'bodily_injuries', 
       'incident_hour_of_the_day','witnesses',
       'police_report_available', 'total_claim_amount', 'injury_claim',
       'property_claim', 'vehicle_claim', 'auto_make', 'auto_model',
       'policy_year']
plt.figure(figsize=(12,30),facecolor='brown')
index=1
for column in columns:
    if index <=36:
        ax = plt.subplot(9,4,index)
        sns.boxplot(df[column], color='c')
        plt.xlabel(column,fontsize=12)
    index+=1
plt.show()

# %% [markdown]
# # Comment:-
# 'age', 'property_claim', 'policy_annual_premium', 'umbrella_limit' have outliers.

# %% [markdown]
# # Removing Outlier

# %%
from scipy.stats import zscore

# Specify the columns to remove outliers
columns_to_remove_outliers = ['age', 'property_claim', 'policy_annual_premium', 'umbrella_limit']

# Calculate z-scores for each specified column
z_scores = df[columns_to_remove_outliers].apply(zscore)

# Set a threshold for z-scores ( 3)
threshold = 3

# Remove rows with z-scores beyond the threshold in any specified column
df1 = df[(z_scores.abs() < threshold).all(axis=1)]

# %% [markdown]
# # Checking Skewness Of Dataset

# %%
plt.figure(figsize=(14,30))
plotnumber=1
for column in columns:
    if plotnumber <=36:
        ax = plt.subplot(9,4,plotnumber)
        sns.distplot(df[column], color='k',hist=False,kde_kws={"shade": True})
        plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.show()

# %%
df.skew()
# Out:
# months_as_customer          0.362177
# age                         0.478988
# policy_state               -0.026177
# policy_csl                  0.088928
# policy_deductable           0.477887
# policy_annual_premium       0.004402
# umbrella_limit              1.806712
# insured_zip                 0.816554
# insured_sex                 0.148630
# insured_education_level    -0.000148
# insured_occupation         -0.058881
# insured_hobbies            -0.061563
# insured_relationship        0.077488
# capital-gains               0.478850
# capital-loss               -0.391472
# incident_date               0.004756
# incident_type               0.101507
# collision_type             -0.033682
# authorities_contacted      -0.121744
# incident_state             -0.148865
# incident_city               0.049531
# incident_location           0.000000
# incident_hour_of_the_day   -0.035584
# property_damage             0.863806
# bodily_injuries             0.014777
# witnesses                   0.019636
# police_report_available     0.802728
# total_claim_amount         -0.594582
# injury_claim                0.264811
# property_claim              0.378169
# vehicle_claim              -0.621098
# auto_make                  -0.018797
# auto_model                 -0.080773
# fraud_reported              1.175051
# policy_year                 0.052511
# dtype: float64

# %% [markdown]
# Comment:-['umbrella_limit' , 'insured_zip','property_damage','police_report_available' ] have Right skewness.

# %% [markdown]
# # Removing Skewness

# %%
# columns with right-skewed data containing zeros
right_skewed = ['umbrella_limit' , 'insured_zip','property_damage','police_report_available' ] 

df[right_skewed] = np.log1p(df[right_skewed]+1)

# Plot the transformed data to check for skewness
sns.histplot(df[right_skewed], kde=True)
plt.title('Log-Transformed Data Distribution')
plt.show()

# %%
df.skew()
# Out:
# months_as_customer          0.362177
# age                         0.478988
# policy_state               -0.026177
# policy_csl                  0.088928
# policy_deductable           0.477887
# policy_annual_premium       0.004402
# umbrella_limit              1.494652
# insured_zip                 0.782405
# insured_sex                 0.148630
# insured_education_level    -0.000148
# insured_occupation         -0.058881
# insured_hobbies            -0.061563
# insured_relationship        0.077488
# capital-gains               0.478850
# capital-loss               -0.391472
# incident_date               0.004756
# incident_type               0.101507
# collision_type             -0.033682
# authorities_contacted      -0.121744
# incident_state             -0.148865
# incident_city               0.049531
# incident_location           0.000000
# incident_hour_of_the_day   -0.035584
# property_damage             0.863806
# bodily_injuries             0.014777
# witnesses                   0.019636
# police_report_available     0.802728
# total_claim_amount         -0.594582
# injury_claim                0.264811
# property_claim              0.378169
# vehicle_claim              -0.621098
# auto_make                  -0.018797
# auto_model                 -0.080773
# fraud_reported              1.175051
# policy_year                 0.052511
# dtype: float64

# %% [markdown]
# # Splitting Dataset

# %%
X = df.drop(columns = ["fraud_reported"])
y = df["fraud_reported"]

# %% [markdown]
# # Standard Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_scaled=scaler.fit_transform(X)

# %%
X['umbrella_limit']=X['umbrella_limit'].fillna(0)

# %%
X.isnull().sum()
# Out:
# months_as_customer          0
# age                         0
# policy_state                0
# policy_csl                  0
# policy_deductable           0
# policy_annual_premium       0
# umbrella_limit              0
# insured_zip                 0
# insured_sex                 0
# insured_education_level     0
# insured_occupation          0
# insured_hobbies             0
# insured_relationship        0
# capital-gains               0
# capital-loss                0
# incident_date               0
# incident_type               0
# collision_type              0
# authorities_contacted       0
# incident_state              0
# incident_city               0
# incident_location           0
# incident_hour_of_the_day    0
# property_damage             0
# bodily_injuries             0
# witnesses                   0
# police_report_available     0
# total_claim_amount          0
# injury_claim                0
# property_claim              0
# vehicle_claim               0
# auto_make                   0
# auto_model                  0
# policy_year                 0
# dtype: int64

# %% [markdown]
# # Machine Learning Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score
from sklearn.metrics import  r2_score

# %%
# Spliting the data for training & testing.
for i in range(1,250):
    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, random_state=i, test_size=.2)
    
X_train.shape
# Out:
# (800, 34)

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
maxAccu=0
maxRS=0
for i in range(1,250):
    X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size = 0.2, random_state=i)
    lr=LogisticRegression()
    lr.fit(X_train,y_train)
    pred=lr.predict(X_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Best accuracy is', maxAccu*100 ,'on Random_state', maxRS)
# Out:
# Best accuracy is 82.5 on Random_state 218

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y,test_size=.2, random_state=218)
lr=LogisticRegression()
lr.fit(X_train,y_train)
pred1=lr.predict(X_test)
print('\033[1m'+'Logistics Regression Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Logistics Regression :'+'\033[0m', accuracy_score(y_test, pred1))
print('\n')
print('\033[1m'+'Confusion matrix of Logistics Regression :'+'\033[0m \n',confusion_matrix(y_test, pred1))
print('\n')
print('\033[1m'+'classification Report of Logistics Regression'+'\033[0m \n',classification_report(y_test, pred1))
# Out:
# Logistics Regression Evaluation
#
#
# Accuracy Score of Logistics Regression : 0.825
#
#
# Confusion matrix of Logistics Regression :
#  [[162   0]
#  [ 35   3]]
#
#
# classification Report of Logistics Regression
#                precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90       162
#            1       1.00      0.08      0.15        38
#
#     accuracy                           0.82       200
#    macro avg       0.91      0.54      0.52       200
# weighted avg       0.86      0.82      0.76       200

# %% [markdown]
# # DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
maxAccu1=0
maxRS1=0
for i in range(1,200):
    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, random_state=i, test_size=.2)
    dtc.fit(X_train,y_train)
    y_pred1=dtc.predict(X_test)
    acc1=accuracy_score(y_test,y_pred1)
    if acc1>maxAccu1:
        maxAccu1=acc1
        maxRS1=i
        
print('Best accuracy Score is: ', (maxAccu1)*100 ,'\nAt Random State: ', maxRS1)
# Out:
# Best accuracy Score is:  76.0
# At Random State:  188

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
models = [SVC(), GaussianNB(), DecisionTreeClassifier(), 
          KNeighborsClassifier(n_neighbors=3), RandomForestClassifier(), ExtraTreesClassifier()]

for model in models:
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print('\033[1m' + 'Classification ML Algorithm Evaluation Matrix for', model.__class__.__name__ + ':' + '\033[0m')
    print('\n')
    print('\033[1m' + 'Accuracy Score :' + '\033[0m\n', accuracy_score(y_test, y_pred))
    print('\n')
    print('\033[1m' + 'Confusion matrix :' + '\033[0m \n', confusion_matrix(y_test, y_pred))
    print('\n')
    print('\033[1m' + 'Classification Report :' + '\033[0m \n', classification_report(y_test, y_pred))
    print('\n')
    
    print('============================================================================================================')
# Out:
# Classification ML Algorithm Evaluation Matrix for SVC:
#
#
# Accuracy Score :
#  0.755
#
#
# Confusion matrix :
#  [[151   0]
#  [ 49   0]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.76      1.00      0.86       151
#            1       0.00      0.00      0.00        49
#
#     accuracy                           0.76       200
#    macro avg       0.38      0.50      0.43       200
# weighted avg       0.57      0.76      0.65       200
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix for GaussianNB:
#
#
# Accuracy Score :
#  0.655
#
#
# Confusion matrix :
#  [[119  32]
#  [ 37  12]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.76      0.79      0.78       151
#            1       0.27      0.24      0.26        49
#
#     accuracy                           0.66       200
#    macro avg       0.52      0.52      0.52       200
# weighted avg       0.64      0.66      0.65       200
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix for DecisionTreeClassifier:
#
#
# Accuracy Score :
#  0.68
#
#
# Confusion matrix :
#  [[123  28]
#  [ 36  13]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.77      0.81      0.79       151
#            1       0.32      0.27      0.29        49
#
#     accuracy                           0.68       200
#    macro avg       0.55      0.54      0.54       200
# weighted avg       0.66      0.68      0.67       200
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix for KNeighborsClassifier:
#
#
# Accuracy Score :
#  0.715
#
#
# Confusion matrix :
#  [[132  19]
#  [ 38  11]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.78      0.87      0.82       151
#            1       0.37      0.22      0.28        49
#
#     accuracy                           0.71       200
#    macro avg       0.57      0.55      0.55       200
# weighted avg       0.68      0.71      0.69       200
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix for RandomForestClassifier:
#
#
# Accuracy Score :
#  0.75
#
#
# Confusion matrix :
#  [[149   2]
#  [ 48   1]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.76      0.99      0.86       151
#            1       0.33      0.02      0.04        49
#
#     accuracy                           0.75       200
#    macro avg       0.54      0.50      0.45       200
# weighted avg       0.65      0.75      0.66       200
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix for ExtraTreesClassifier:
#
#
# Accuracy Score :
#  0.755
#
#
# Confusion matrix :
#  [[151   0]
#  [ 49   0]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.76      1.00      0.86       151
#            1       0.00      0.00      0.00        49
#
#     accuracy                           0.76       200
#    macro avg       0.38      0.50      0.43       200
# weighted avg       0.57      0.76      0.65       200
#
#
#
# ============================================================================================================

# %% [markdown]
# # Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param = {
    'penalty': ['l1', 'l2'],
    'C': [0.001, 0.01, 0.1, 1, 10],
    'solver': ['liblinear', 'lbfgs', 'saga'],
    'max_iter': [100, 200, 300],
    'class_weight': [None, 'balanced']
}

# %%
grid_search = GridSearchCV(LogisticRegression(),param, cv=5, scoring='accuracy',verbose=5)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# [CV 1/5] END C=0.001, class_weight=None, max_iter=100, penalty=l1, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=None, max_iter=100, penalty=l1, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=None, max_iter=100, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=None, max_iter=100, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=None, max_iter=100, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=None, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=None, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=None, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=None, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=None, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=None, max_iter=100, penalty=l1, solver=saga;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=None, max_iter=100, penalty=l1, solver=saga;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=None, max_iter=100, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=None, max_iter=100, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=None, max_iter=100, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=None, max_iter=100, penalty=l2, solver=liblinear;, score=0.738 total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=None, max_iter=100, penalty=l2, solver=liblinear;, score=0.694 total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=None, max_iter=100, penalty=l2, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=None, max_iter=100, penalty=l2, solver=liblinear;, score=0.744 total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=None, max_iter=100, penalty=l2, solver=liblinear;, score=0.725 total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=None, max_iter=100, penalty=l2, solver=lbfgs;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=None, max_iter=100, penalty=l2, solver=lbfgs;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=None, max_iter=100, penalty=l2, solver=lbfgs;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=None, max_iter=100, penalty=l2, solver=lbfgs;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=None, max_iter=100, penalty=l2, solver=lbfgs;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=None, max_iter=100, penalty=l2, solver=saga;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=None, max_iter=100, penalty=l2, solver=saga;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=None, max_iter=100, penalty=l2, solver=saga;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=None, max_iter=100, penalty=l2, solver=saga;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=None, max_iter=100, penalty=l2, solver=saga;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=None, max_iter=200, penalty=l1, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=None, max_iter=200, penalty=l1, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=None, max_iter=200, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=None, max_iter=200, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=None, max_iter=200, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=None, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=None, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=None, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=None, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=None, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=None, max_iter=200, penalty=l1, solver=saga;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=None, max_iter=200, penalty=l1, solver=saga;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=None, max_iter=200, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=None, max_iter=200, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=None, max_iter=200, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=None, max_iter=200, penalty=l2, solver=liblinear;, score=0.738 total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=None, max_iter=200, penalty=l2, solver=liblinear;, score=0.694 total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=None, max_iter=200, penalty=l2, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=None, max_iter=200, penalty=l2, solver=liblinear;, score=0.744 total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=None, max_iter=200, penalty=l2, solver=liblinear;, score=0.725 total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=None, max_iter=200, penalty=l2, solver=lbfgs;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=None, max_iter=200, penalty=l2, solver=lbfgs;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=None, max_iter=200, penalty=l2, solver=lbfgs;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=None, max_iter=200, penalty=l2, solver=lbfgs;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=None, max_iter=200, penalty=l2, solver=lbfgs;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=None, max_iter=200, penalty=l2, solver=saga;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=None, max_iter=200, penalty=l2, solver=saga;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=None, max_iter=200, penalty=l2, solver=saga;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=None, max_iter=200, penalty=l2, solver=saga;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=None, max_iter=200, penalty=l2, solver=saga;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=None, max_iter=300, penalty=l1, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=None, max_iter=300, penalty=l1, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=None, max_iter=300, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=None, max_iter=300, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=None, max_iter=300, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=None, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=None, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=None, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=None, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=None, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=None, max_iter=300, penalty=l1, solver=saga;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=None, max_iter=300, penalty=l1, solver=saga;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=None, max_iter=300, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=None, max_iter=300, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=None, max_iter=300, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=None, max_iter=300, penalty=l2, solver=liblinear;, score=0.738 total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=None, max_iter=300, penalty=l2, solver=liblinear;, score=0.694 total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=None, max_iter=300, penalty=l2, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=None, max_iter=300, penalty=l2, solver=liblinear;, score=0.744 total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=None, max_iter=300, penalty=l2, solver=liblinear;, score=0.725 total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=None, max_iter=300, penalty=l2, solver=lbfgs;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=None, max_iter=300, penalty=l2, solver=lbfgs;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=None, max_iter=300, penalty=l2, solver=lbfgs;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=None, max_iter=300, penalty=l2, solver=lbfgs;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=None, max_iter=300, penalty=l2, solver=lbfgs;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=None, max_iter=300, penalty=l2, solver=saga;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=None, max_iter=300, penalty=l2, solver=saga;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=None, max_iter=300, penalty=l2, solver=saga;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=None, max_iter=300, penalty=l2, solver=saga;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=None, max_iter=300, penalty=l2, solver=saga;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, max_iter=100, penalty=l1, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, max_iter=100, penalty=l1, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, max_iter=100, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, max_iter=100, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, max_iter=100, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, max_iter=100, penalty=l1, solver=saga;, score=0.244 total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, max_iter=100, penalty=l1, solver=saga;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, max_iter=100, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, max_iter=100, penalty=l1, solver=saga;, score=0.250 total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, max_iter=100, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, max_iter=100, penalty=l2, solver=liblinear;, score=0.425 total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, max_iter=100, penalty=l2, solver=liblinear;, score=0.550 total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, max_iter=100, penalty=l2, solver=liblinear;, score=0.512 total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, max_iter=100, penalty=l2, solver=liblinear;, score=0.525 total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, max_iter=100, penalty=l2, solver=liblinear;, score=0.463 total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, max_iter=100, penalty=l2, solver=lbfgs;, score=0.463 total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, max_iter=100, penalty=l2, solver=lbfgs;, score=0.550 total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, max_iter=100, penalty=l2, solver=lbfgs;, score=0.537 total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, max_iter=100, penalty=l2, solver=lbfgs;, score=0.531 total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, max_iter=100, penalty=l2, solver=lbfgs;, score=0.494 total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, max_iter=100, penalty=l2, solver=saga;, score=0.463 total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, max_iter=100, penalty=l2, solver=saga;, score=0.550 total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, max_iter=100, penalty=l2, solver=saga;, score=0.537 total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, max_iter=100, penalty=l2, solver=saga;, score=0.531 total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, max_iter=100, penalty=l2, solver=saga;, score=0.494 total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, max_iter=200, penalty=l1, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, max_iter=200, penalty=l1, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, max_iter=200, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, max_iter=200, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, max_iter=200, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, max_iter=200, penalty=l1, solver=saga;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, max_iter=200, penalty=l1, solver=saga;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, max_iter=200, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, max_iter=200, penalty=l1, solver=saga;, score=0.250 total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, max_iter=200, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, max_iter=200, penalty=l2, solver=liblinear;, score=0.425 total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, max_iter=200, penalty=l2, solver=liblinear;, score=0.550 total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, max_iter=200, penalty=l2, solver=liblinear;, score=0.512 total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, max_iter=200, penalty=l2, solver=liblinear;, score=0.525 total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, max_iter=200, penalty=l2, solver=liblinear;, score=0.463 total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, max_iter=200, penalty=l2, solver=lbfgs;, score=0.463 total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, max_iter=200, penalty=l2, solver=lbfgs;, score=0.550 total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, max_iter=200, penalty=l2, solver=lbfgs;, score=0.537 total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, max_iter=200, penalty=l2, solver=lbfgs;, score=0.531 total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, max_iter=200, penalty=l2, solver=lbfgs;, score=0.494 total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, max_iter=200, penalty=l2, solver=saga;, score=0.463 total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, max_iter=200, penalty=l2, solver=saga;, score=0.550 total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, max_iter=200, penalty=l2, solver=saga;, score=0.537 total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, max_iter=200, penalty=l2, solver=saga;, score=0.531 total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, max_iter=200, penalty=l2, solver=saga;, score=0.494 total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, max_iter=300, penalty=l1, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, max_iter=300, penalty=l1, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, max_iter=300, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, max_iter=300, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, max_iter=300, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, max_iter=300, penalty=l1, solver=saga;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, max_iter=300, penalty=l1, solver=saga;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, max_iter=300, penalty=l1, solver=saga;, score=0.250 total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, max_iter=300, penalty=l1, solver=saga;, score=0.250 total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, max_iter=300, penalty=l1, solver=saga;, score=0.250 total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, max_iter=300, penalty=l2, solver=liblinear;, score=0.425 total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, max_iter=300, penalty=l2, solver=liblinear;, score=0.550 total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, max_iter=300, penalty=l2, solver=liblinear;, score=0.512 total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, max_iter=300, penalty=l2, solver=liblinear;, score=0.525 total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, max_iter=300, penalty=l2, solver=liblinear;, score=0.463 total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, max_iter=300, penalty=l2, solver=lbfgs;, score=0.463 total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, max_iter=300, penalty=l2, solver=lbfgs;, score=0.550 total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, max_iter=300, penalty=l2, solver=lbfgs;, score=0.537 total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, max_iter=300, penalty=l2, solver=lbfgs;, score=0.531 total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, max_iter=300, penalty=l2, solver=lbfgs;, score=0.494 total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, max_iter=300, penalty=l2, solver=saga;, score=0.463 total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, max_iter=300, penalty=l2, solver=saga;, score=0.550 total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, max_iter=300, penalty=l2, solver=saga;, score=0.537 total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, max_iter=300, penalty=l2, solver=saga;, score=0.531 total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, max_iter=300, penalty=l2, solver=saga;, score=0.494 total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=None, max_iter=100, penalty=l1, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=None, max_iter=100, penalty=l1, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=None, max_iter=100, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=None, max_iter=100, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=None, max_iter=100, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=None, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=None, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=None, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=None, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=None, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=None, max_iter=100, penalty=l1, solver=saga;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=None, max_iter=100, penalty=l1, solver=saga;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=None, max_iter=100, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=None, max_iter=100, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=None, max_iter=100, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=None, max_iter=100, penalty=l2, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=None, max_iter=100, penalty=l2, solver=liblinear;, score=0.738 total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=None, max_iter=100, penalty=l2, solver=liblinear;, score=0.731 total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=None, max_iter=100, penalty=l2, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=None, max_iter=100, penalty=l2, solver=liblinear;, score=0.744 total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=None, max_iter=100, penalty=l2, solver=lbfgs;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=None, max_iter=100, penalty=l2, solver=lbfgs;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=None, max_iter=100, penalty=l2, solver=lbfgs;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=None, max_iter=100, penalty=l2, solver=lbfgs;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=None, max_iter=100, penalty=l2, solver=lbfgs;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=None, max_iter=100, penalty=l2, solver=saga;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=None, max_iter=100, penalty=l2, solver=saga;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=None, max_iter=100, penalty=l2, solver=saga;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=None, max_iter=100, penalty=l2, solver=saga;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=None, max_iter=100, penalty=l2, solver=saga;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=None, max_iter=200, penalty=l1, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=None, max_iter=200, penalty=l1, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=None, max_iter=200, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=None, max_iter=200, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=None, max_iter=200, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=None, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=None, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=None, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=None, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=None, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=None, max_iter=200, penalty=l1, solver=saga;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=None, max_iter=200, penalty=l1, solver=saga;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=None, max_iter=200, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=None, max_iter=200, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=None, max_iter=200, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=None, max_iter=200, penalty=l2, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=None, max_iter=200, penalty=l2, solver=liblinear;, score=0.738 total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=None, max_iter=200, penalty=l2, solver=liblinear;, score=0.731 total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=None, max_iter=200, penalty=l2, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=None, max_iter=200, penalty=l2, solver=liblinear;, score=0.744 total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=None, max_iter=200, penalty=l2, solver=lbfgs;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=None, max_iter=200, penalty=l2, solver=lbfgs;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=None, max_iter=200, penalty=l2, solver=lbfgs;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=None, max_iter=200, penalty=l2, solver=lbfgs;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=None, max_iter=200, penalty=l2, solver=lbfgs;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=None, max_iter=200, penalty=l2, solver=saga;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=None, max_iter=200, penalty=l2, solver=saga;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=None, max_iter=200, penalty=l2, solver=saga;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=None, max_iter=200, penalty=l2, solver=saga;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=None, max_iter=200, penalty=l2, solver=saga;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=None, max_iter=300, penalty=l1, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=None, max_iter=300, penalty=l1, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=None, max_iter=300, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=None, max_iter=300, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=None, max_iter=300, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=None, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=None, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=None, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=None, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=None, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=None, max_iter=300, penalty=l1, solver=saga;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=None, max_iter=300, penalty=l1, solver=saga;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=None, max_iter=300, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=None, max_iter=300, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=None, max_iter=300, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=None, max_iter=300, penalty=l2, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=None, max_iter=300, penalty=l2, solver=liblinear;, score=0.738 total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=None, max_iter=300, penalty=l2, solver=liblinear;, score=0.731 total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=None, max_iter=300, penalty=l2, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=None, max_iter=300, penalty=l2, solver=liblinear;, score=0.744 total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=None, max_iter=300, penalty=l2, solver=lbfgs;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=None, max_iter=300, penalty=l2, solver=lbfgs;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=None, max_iter=300, penalty=l2, solver=lbfgs;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=None, max_iter=300, penalty=l2, solver=lbfgs;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=None, max_iter=300, penalty=l2, solver=lbfgs;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=None, max_iter=300, penalty=l2, solver=saga;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=None, max_iter=300, penalty=l2, solver=saga;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=None, max_iter=300, penalty=l2, solver=saga;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=None, max_iter=300, penalty=l2, solver=saga;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=None, max_iter=300, penalty=l2, solver=saga;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=balanced, max_iter=100, penalty=l1, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=balanced, max_iter=100, penalty=l1, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=balanced, max_iter=100, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=balanced, max_iter=100, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=balanced, max_iter=100, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=balanced, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=balanced, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=balanced, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=balanced, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=balanced, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=balanced, max_iter=100, penalty=l1, solver=saga;, score=0.244 total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=balanced, max_iter=100, penalty=l1, solver=saga;, score=0.244 total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=balanced, max_iter=100, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=balanced, max_iter=100, penalty=l1, solver=saga;, score=0.250 total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=balanced, max_iter=100, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=balanced, max_iter=100, penalty=l2, solver=liblinear;, score=0.475 total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=balanced, max_iter=100, penalty=l2, solver=liblinear;, score=0.525 total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=balanced, max_iter=100, penalty=l2, solver=liblinear;, score=0.525 total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=balanced, max_iter=100, penalty=l2, solver=liblinear;, score=0.537 total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=balanced, max_iter=100, penalty=l2, solver=liblinear;, score=0.506 total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=balanced, max_iter=100, penalty=l2, solver=lbfgs;, score=0.487 total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=balanced, max_iter=100, penalty=l2, solver=lbfgs;, score=0.525 total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=balanced, max_iter=100, penalty=l2, solver=lbfgs;, score=0.544 total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=balanced, max_iter=100, penalty=l2, solver=lbfgs;, score=0.531 total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=balanced, max_iter=100, penalty=l2, solver=lbfgs;, score=0.531 total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=balanced, max_iter=100, penalty=l2, solver=saga;, score=0.487 total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=balanced, max_iter=100, penalty=l2, solver=saga;, score=0.525 total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=balanced, max_iter=100, penalty=l2, solver=saga;, score=0.544 total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=balanced, max_iter=100, penalty=l2, solver=saga;, score=0.531 total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=balanced, max_iter=100, penalty=l2, solver=saga;, score=0.531 total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=balanced, max_iter=200, penalty=l1, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=balanced, max_iter=200, penalty=l1, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=balanced, max_iter=200, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=balanced, max_iter=200, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=balanced, max_iter=200, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=balanced, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=balanced, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=balanced, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=balanced, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=balanced, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=balanced, max_iter=200, penalty=l1, solver=saga;, score=0.244 total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=balanced, max_iter=200, penalty=l1, solver=saga;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=balanced, max_iter=200, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=balanced, max_iter=200, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=balanced, max_iter=200, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=balanced, max_iter=200, penalty=l2, solver=liblinear;, score=0.475 total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=balanced, max_iter=200, penalty=l2, solver=liblinear;, score=0.525 total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=balanced, max_iter=200, penalty=l2, solver=liblinear;, score=0.525 total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=balanced, max_iter=200, penalty=l2, solver=liblinear;, score=0.537 total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=balanced, max_iter=200, penalty=l2, solver=liblinear;, score=0.506 total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=balanced, max_iter=200, penalty=l2, solver=lbfgs;, score=0.487 total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=balanced, max_iter=200, penalty=l2, solver=lbfgs;, score=0.525 total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=balanced, max_iter=200, penalty=l2, solver=lbfgs;, score=0.544 total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=balanced, max_iter=200, penalty=l2, solver=lbfgs;, score=0.531 total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=balanced, max_iter=200, penalty=l2, solver=lbfgs;, score=0.531 total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=balanced, max_iter=200, penalty=l2, solver=saga;, score=0.487 total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=balanced, max_iter=200, penalty=l2, solver=saga;, score=0.525 total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=balanced, max_iter=200, penalty=l2, solver=saga;, score=0.544 total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=balanced, max_iter=200, penalty=l2, solver=saga;, score=0.531 total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=balanced, max_iter=200, penalty=l2, solver=saga;, score=0.531 total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=balanced, max_iter=300, penalty=l1, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=balanced, max_iter=300, penalty=l1, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=balanced, max_iter=300, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=balanced, max_iter=300, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=balanced, max_iter=300, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=balanced, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=balanced, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=balanced, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=balanced, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=balanced, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=balanced, max_iter=300, penalty=l1, solver=saga;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=balanced, max_iter=300, penalty=l1, solver=saga;, score=0.244 total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=balanced, max_iter=300, penalty=l1, solver=saga;, score=0.250 total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=balanced, max_iter=300, penalty=l1, solver=saga;, score=0.250 total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=balanced, max_iter=300, penalty=l1, solver=saga;, score=0.250 total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=balanced, max_iter=300, penalty=l2, solver=liblinear;, score=0.475 total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=balanced, max_iter=300, penalty=l2, solver=liblinear;, score=0.525 total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=balanced, max_iter=300, penalty=l2, solver=liblinear;, score=0.525 total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=balanced, max_iter=300, penalty=l2, solver=liblinear;, score=0.537 total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=balanced, max_iter=300, penalty=l2, solver=liblinear;, score=0.506 total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=balanced, max_iter=300, penalty=l2, solver=lbfgs;, score=0.487 total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=balanced, max_iter=300, penalty=l2, solver=lbfgs;, score=0.525 total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=balanced, max_iter=300, penalty=l2, solver=lbfgs;, score=0.544 total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=balanced, max_iter=300, penalty=l2, solver=lbfgs;, score=0.531 total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=balanced, max_iter=300, penalty=l2, solver=lbfgs;, score=0.531 total time=   0.0s
# [CV 1/5] END C=0.01, class_weight=balanced, max_iter=300, penalty=l2, solver=saga;, score=0.487 total time=   0.0s
# [CV 2/5] END C=0.01, class_weight=balanced, max_iter=300, penalty=l2, solver=saga;, score=0.525 total time=   0.0s
# [CV 3/5] END C=0.01, class_weight=balanced, max_iter=300, penalty=l2, solver=saga;, score=0.544 total time=   0.0s
# [CV 4/5] END C=0.01, class_weight=balanced, max_iter=300, penalty=l2, solver=saga;, score=0.531 total time=   0.0s
# [CV 5/5] END C=0.01, class_weight=balanced, max_iter=300, penalty=l2, solver=saga;, score=0.531 total time=   0.0s
# [CV 1/5] END C=0.1, class_weight=None, max_iter=100, penalty=l1, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.1, class_weight=None, max_iter=100, penalty=l1, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.1, class_weight=None, max_iter=100, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.1, class_weight=None, max_iter=100, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.1, class_weight=None, max_iter=100, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.1, class_weight=None, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.1, class_weight=None, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.1, class_weight=None, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.1, class_weight=None, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.1, class_weight=None, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.1, class_weight=None, max_iter=100, penalty=l1, solver=saga;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.1, class_weight=None, max_iter=100, penalty=l1, solver=saga;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.1, class_weight=None, max_iter=100, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.1, class_weight=None, max_iter=100, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.1, class_weight=None, max_iter=100, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.1, class_weight=None, max_iter=100, penalty=l2, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.1, class_weight=None, max_iter=100, penalty=l2, solver=liblinear;, score=0.731 total time=   0.0s
# [CV 3/5] END C=0.1, class_weight=None, max_iter=100, penalty=l2, solver=liblinear;, score=0.738 total time=   0.0s
# [CV 4/5] END C=0.1, class_weight=None, max_iter=100, penalty=l2, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.1, class_weight=None, max_iter=100, penalty=l2, solver=liblinear;, score=0.744 total time=   0.0s
# [CV 1/5] END C=0.1, class_weight=None, max_iter=100, penalty=l2, solver=lbfgs;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.1, class_weight=None, max_iter=100, penalty=l2, solver=lbfgs;, score=0.731 total time=   0.0s
# [CV 3/5] END C=0.1, class_weight=None, max_iter=100, penalty=l2, solver=lbfgs;, score=0.738 total time=   0.0s
# [CV 4/5] END C=0.1, class_weight=None, max_iter=100, penalty=l2, solver=lbfgs;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.1, class_weight=None, max_iter=100, penalty=l2, solver=lbfgs;, score=0.744 total time=   0.0s
# [CV 1/5] END C=0.1, class_weight=None, max_iter=100, penalty=l2, solver=saga;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.1, class_weight=None, max_iter=100, penalty=l2, solver=saga;, score=0.731 total time=   0.0s
# [CV 3/5] END C=0.1, class_weight=None, max_iter=100, penalty=l2, solver=saga;, score=0.738 total time=   0.0s
# [CV 4/5] END C=0.1, class_weight=None, max_iter=100, penalty=l2, solver=saga;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.1, class_weight=None, max_iter=100, penalty=l2, solver=saga;, score=0.744 total time=   0.0s
# [CV 1/5] END C=0.1, class_weight=None, max_iter=200, penalty=l1, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.1, class_weight=None, max_iter=200, penalty=l1, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.1, class_weight=None, max_iter=200, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.1, class_weight=None, max_iter=200, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.1, class_weight=None, max_iter=200, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.1, class_weight=None, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.1, class_weight=None, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.1, class_weight=None, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.1, class_weight=None, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.1, class_weight=None, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.1, class_weight=None, max_iter=200, penalty=l1, solver=saga;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.1, class_weight=None, max_iter=200, penalty=l1, solver=saga;, score=0.756 total time=   0.0s
# [CV 3/5] END C=0.1, class_weight=None, max_iter=200, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.1, class_weight=None, max_iter=200, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.1, class_weight=None, max_iter=200, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.1, class_weight=None, max_iter=200, penalty=l2, solver=liblinear;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.1, class_weight=None, max_iter=200, penalty=l2, solver=liblinear;, score=0.731 total time=   0.0s
# [CV 3/5] END C=0.1, class_weight=None, max_iter=200, penalty=l2, solver=liblinear;, score=0.738 total time=   0.0s
# [CV 4/5] END C=0.1, class_weight=None, max_iter=200, penalty=l2, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.1, class_weight=None, max_iter=200, penalty=l2, solver=liblinear;, score=0.744 total time=   0.0s
# [CV 1/5] END C=0.1, class_weight=None, max_iter=200, penalty=l2, solver=lbfgs;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.1, class_weight=None, max_iter=200, penalty=l2, solver=lbfgs;, score=0.731 total time=   0.0s
# [CV 3/5] END C=0.1, class_weight=None, max_iter=200, penalty=l2, solver=lbfgs;, score=0.738 total time=   0.0s
# [CV 4/5] END C=0.1, class_weight=None, max_iter=200, penalty=l2, solver=lbfgs;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.1, class_weight=None, max_iter=200, penalty=l2, solver=lbfgs;, score=0.744 total time=   0.0s
# [CV 1/5] END C=0.1, class_weight=None, max_iter=200, penalty=l2, solver=saga;, score=0.756 total time=   0.0s
# [CV 2/5] END C=0.1, class_weight=None, max_iter=200, penalty=l2, solver=saga;, score=0.731 total time=   0.0s
# ...
# [CV 3/5] END C=10, class_weight=None, max_iter=200, penalty=l1, solver=saga;, score=0.738 total time=   0.0s
# [CV 4/5] END C=10, class_weight=None, max_iter=200, penalty=l1, solver=saga;, score=0.744 total time=   0.0s
# [CV 5/5] END C=10, class_weight=None, max_iter=200, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 1/5] END C=10, class_weight=None, max_iter=200, penalty=l2, solver=liblinear;, score=0.744 total time=   0.0s
# [CV 2/5] END C=10, class_weight=None, max_iter=200, penalty=l2, solver=liblinear;, score=0.713 total time=   0.0s
# [CV 3/5] END C=10, class_weight=None, max_iter=200, penalty=l2, solver=liblinear;, score=0.738 total time=   0.0s
# [CV 4/5] END C=10, class_weight=None, max_iter=200, penalty=l2, solver=liblinear;, score=0.744 total time=   0.0s
# [CV 5/5] END C=10, class_weight=None, max_iter=200, penalty=l2, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 1/5] END C=10, class_weight=None, max_iter=200, penalty=l2, solver=lbfgs;, score=0.744 total time=   0.0s
# [CV 2/5] END C=10, class_weight=None, max_iter=200, penalty=l2, solver=lbfgs;, score=0.713 total time=   0.0s
# [CV 3/5] END C=10, class_weight=None, max_iter=200, penalty=l2, solver=lbfgs;, score=0.738 total time=   0.0s
# [CV 4/5] END C=10, class_weight=None, max_iter=200, penalty=l2, solver=lbfgs;, score=0.744 total time=   0.0s
# [CV 5/5] END C=10, class_weight=None, max_iter=200, penalty=l2, solver=lbfgs;, score=0.750 total time=   0.0s
# [CV 1/5] END C=10, class_weight=None, max_iter=200, penalty=l2, solver=saga;, score=0.744 total time=   0.0s
# [CV 2/5] END C=10, class_weight=None, max_iter=200, penalty=l2, solver=saga;, score=0.713 total time=   0.0s
# [CV 3/5] END C=10, class_weight=None, max_iter=200, penalty=l2, solver=saga;, score=0.738 total time=   0.0s
# [CV 4/5] END C=10, class_weight=None, max_iter=200, penalty=l2, solver=saga;, score=0.744 total time=   0.0s
# [CV 5/5] END C=10, class_weight=None, max_iter=200, penalty=l2, solver=saga;, score=0.750 total time=   0.0s
# [CV 1/5] END C=10, class_weight=None, max_iter=300, penalty=l1, solver=liblinear;, score=0.744 total time=   0.0s
# [CV 2/5] END C=10, class_weight=None, max_iter=300, penalty=l1, solver=liblinear;, score=0.713 total time=   0.0s
# [CV 3/5] END C=10, class_weight=None, max_iter=300, penalty=l1, solver=liblinear;, score=0.738 total time=   0.0s
# [CV 4/5] END C=10, class_weight=None, max_iter=300, penalty=l1, solver=liblinear;, score=0.744 total time=   0.0s
# [CV 5/5] END C=10, class_weight=None, max_iter=300, penalty=l1, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 1/5] END C=10, class_weight=None, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=10, class_weight=None, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=10, class_weight=None, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=10, class_weight=None, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=10, class_weight=None, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=10, class_weight=None, max_iter=300, penalty=l1, solver=saga;, score=0.744 total time=   0.0s
# [CV 2/5] END C=10, class_weight=None, max_iter=300, penalty=l1, solver=saga;, score=0.713 total time=   0.0s
# [CV 3/5] END C=10, class_weight=None, max_iter=300, penalty=l1, solver=saga;, score=0.738 total time=   0.0s
# [CV 4/5] END C=10, class_weight=None, max_iter=300, penalty=l1, solver=saga;, score=0.744 total time=   0.0s
# [CV 5/5] END C=10, class_weight=None, max_iter=300, penalty=l1, solver=saga;, score=0.750 total time=   0.0s
# [CV 1/5] END C=10, class_weight=None, max_iter=300, penalty=l2, solver=liblinear;, score=0.744 total time=   0.0s
# [CV 2/5] END C=10, class_weight=None, max_iter=300, penalty=l2, solver=liblinear;, score=0.713 total time=   0.0s
# [CV 3/5] END C=10, class_weight=None, max_iter=300, penalty=l2, solver=liblinear;, score=0.738 total time=   0.0s
# [CV 4/5] END C=10, class_weight=None, max_iter=300, penalty=l2, solver=liblinear;, score=0.744 total time=   0.0s
# [CV 5/5] END C=10, class_weight=None, max_iter=300, penalty=l2, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 1/5] END C=10, class_weight=None, max_iter=300, penalty=l2, solver=lbfgs;, score=0.744 total time=   0.0s
# [CV 2/5] END C=10, class_weight=None, max_iter=300, penalty=l2, solver=lbfgs;, score=0.713 total time=   0.0s
# [CV 3/5] END C=10, class_weight=None, max_iter=300, penalty=l2, solver=lbfgs;, score=0.738 total time=   0.0s
# [CV 4/5] END C=10, class_weight=None, max_iter=300, penalty=l2, solver=lbfgs;, score=0.744 total time=   0.0s
# [CV 5/5] END C=10, class_weight=None, max_iter=300, penalty=l2, solver=lbfgs;, score=0.750 total time=   0.0s
# [CV 1/5] END C=10, class_weight=None, max_iter=300, penalty=l2, solver=saga;, score=0.744 total time=   0.0s
# [CV 2/5] END C=10, class_weight=None, max_iter=300, penalty=l2, solver=saga;, score=0.713 total time=   0.0s
# [CV 3/5] END C=10, class_weight=None, max_iter=300, penalty=l2, solver=saga;, score=0.738 total time=   0.0s
# [CV 4/5] END C=10, class_weight=None, max_iter=300, penalty=l2, solver=saga;, score=0.744 total time=   0.0s
# [CV 5/5] END C=10, class_weight=None, max_iter=300, penalty=l2, solver=saga;, score=0.750 total time=   0.0s
# [CV 1/5] END C=10, class_weight=balanced, max_iter=100, penalty=l1, solver=liblinear;, score=0.537 total time=   0.0s
# [CV 2/5] END C=10, class_weight=balanced, max_iter=100, penalty=l1, solver=liblinear;, score=0.506 total time=   0.0s
# [CV 3/5] END C=10, class_weight=balanced, max_iter=100, penalty=l1, solver=liblinear;, score=0.562 total time=   0.0s
# [CV 4/5] END C=10, class_weight=balanced, max_iter=100, penalty=l1, solver=liblinear;, score=0.556 total time=   0.0s
# [CV 5/5] END C=10, class_weight=balanced, max_iter=100, penalty=l1, solver=liblinear;, score=0.506 total time=   0.0s
# [CV 1/5] END C=10, class_weight=balanced, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=10, class_weight=balanced, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=10, class_weight=balanced, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=10, class_weight=balanced, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=10, class_weight=balanced, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=10, class_weight=balanced, max_iter=100, penalty=l1, solver=saga;, score=0.537 total time=   0.0s
# [CV 2/5] END C=10, class_weight=balanced, max_iter=100, penalty=l1, solver=saga;, score=0.506 total time=   0.0s
# [CV 3/5] END C=10, class_weight=balanced, max_iter=100, penalty=l1, solver=saga;, score=0.562 total time=   0.0s
# [CV 4/5] END C=10, class_weight=balanced, max_iter=100, penalty=l1, solver=saga;, score=0.556 total time=   0.0s
# [CV 5/5] END C=10, class_weight=balanced, max_iter=100, penalty=l1, solver=saga;, score=0.506 total time=   0.0s
# [CV 1/5] END C=10, class_weight=balanced, max_iter=100, penalty=l2, solver=liblinear;, score=0.531 total time=   0.0s
# [CV 2/5] END C=10, class_weight=balanced, max_iter=100, penalty=l2, solver=liblinear;, score=0.506 total time=   0.0s
# [CV 3/5] END C=10, class_weight=balanced, max_iter=100, penalty=l2, solver=liblinear;, score=0.556 total time=   0.0s
# [CV 4/5] END C=10, class_weight=balanced, max_iter=100, penalty=l2, solver=liblinear;, score=0.550 total time=   0.0s
# [CV 5/5] END C=10, class_weight=balanced, max_iter=100, penalty=l2, solver=liblinear;, score=0.506 total time=   0.0s
# [CV 1/5] END C=10, class_weight=balanced, max_iter=100, penalty=l2, solver=lbfgs;, score=0.531 total time=   0.0s
# [CV 2/5] END C=10, class_weight=balanced, max_iter=100, penalty=l2, solver=lbfgs;, score=0.506 total time=   0.0s
# [CV 3/5] END C=10, class_weight=balanced, max_iter=100, penalty=l2, solver=lbfgs;, score=0.556 total time=   0.0s
# [CV 4/5] END C=10, class_weight=balanced, max_iter=100, penalty=l2, solver=lbfgs;, score=0.550 total time=   0.0s
# [CV 5/5] END C=10, class_weight=balanced, max_iter=100, penalty=l2, solver=lbfgs;, score=0.506 total time=   0.0s
# [CV 1/5] END C=10, class_weight=balanced, max_iter=100, penalty=l2, solver=saga;, score=0.531 total time=   0.0s
# [CV 2/5] END C=10, class_weight=balanced, max_iter=100, penalty=l2, solver=saga;, score=0.506 total time=   0.0s
# [CV 3/5] END C=10, class_weight=balanced, max_iter=100, penalty=l2, solver=saga;, score=0.556 total time=   0.0s
# [CV 4/5] END C=10, class_weight=balanced, max_iter=100, penalty=l2, solver=saga;, score=0.550 total time=   0.0s
# [CV 5/5] END C=10, class_weight=balanced, max_iter=100, penalty=l2, solver=saga;, score=0.506 total time=   0.0s
# [CV 1/5] END C=10, class_weight=balanced, max_iter=200, penalty=l1, solver=liblinear;, score=0.537 total time=   0.0s
# [CV 2/5] END C=10, class_weight=balanced, max_iter=200, penalty=l1, solver=liblinear;, score=0.506 total time=   0.0s
# [CV 3/5] END C=10, class_weight=balanced, max_iter=200, penalty=l1, solver=liblinear;, score=0.562 total time=   0.0s
# [CV 4/5] END C=10, class_weight=balanced, max_iter=200, penalty=l1, solver=liblinear;, score=0.556 total time=   0.0s
# [CV 5/5] END C=10, class_weight=balanced, max_iter=200, penalty=l1, solver=liblinear;, score=0.506 total time=   0.0s
# [CV 1/5] END C=10, class_weight=balanced, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=10, class_weight=balanced, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=10, class_weight=balanced, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=10, class_weight=balanced, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=10, class_weight=balanced, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=10, class_weight=balanced, max_iter=200, penalty=l1, solver=saga;, score=0.537 total time=   0.0s
# [CV 2/5] END C=10, class_weight=balanced, max_iter=200, penalty=l1, solver=saga;, score=0.506 total time=   0.0s
# [CV 3/5] END C=10, class_weight=balanced, max_iter=200, penalty=l1, solver=saga;, score=0.562 total time=   0.0s
# [CV 4/5] END C=10, class_weight=balanced, max_iter=200, penalty=l1, solver=saga;, score=0.556 total time=   0.0s
# [CV 5/5] END C=10, class_weight=balanced, max_iter=200, penalty=l1, solver=saga;, score=0.506 total time=   0.0s
# [CV 1/5] END C=10, class_weight=balanced, max_iter=200, penalty=l2, solver=liblinear;, score=0.531 total time=   0.0s
# [CV 2/5] END C=10, class_weight=balanced, max_iter=200, penalty=l2, solver=liblinear;, score=0.506 total time=   0.0s
# [CV 3/5] END C=10, class_weight=balanced, max_iter=200, penalty=l2, solver=liblinear;, score=0.556 total time=   0.0s
# [CV 4/5] END C=10, class_weight=balanced, max_iter=200, penalty=l2, solver=liblinear;, score=0.550 total time=   0.0s
# [CV 5/5] END C=10, class_weight=balanced, max_iter=200, penalty=l2, solver=liblinear;, score=0.506 total time=   0.0s
# [CV 1/5] END C=10, class_weight=balanced, max_iter=200, penalty=l2, solver=lbfgs;, score=0.531 total time=   0.0s
# [CV 2/5] END C=10, class_weight=balanced, max_iter=200, penalty=l2, solver=lbfgs;, score=0.506 total time=   0.0s
# [CV 3/5] END C=10, class_weight=balanced, max_iter=200, penalty=l2, solver=lbfgs;, score=0.556 total time=   0.0s
# [CV 4/5] END C=10, class_weight=balanced, max_iter=200, penalty=l2, solver=lbfgs;, score=0.550 total time=   0.0s
# [CV 5/5] END C=10, class_weight=balanced, max_iter=200, penalty=l2, solver=lbfgs;, score=0.506 total time=   0.0s
# [CV 1/5] END C=10, class_weight=balanced, max_iter=200, penalty=l2, solver=saga;, score=0.531 total time=   0.0s
# [CV 2/5] END C=10, class_weight=balanced, max_iter=200, penalty=l2, solver=saga;, score=0.506 total time=   0.0s
# [CV 3/5] END C=10, class_weight=balanced, max_iter=200, penalty=l2, solver=saga;, score=0.556 total time=   0.0s
# [CV 4/5] END C=10, class_weight=balanced, max_iter=200, penalty=l2, solver=saga;, score=0.550 total time=   0.0s
# [CV 5/5] END C=10, class_weight=balanced, max_iter=200, penalty=l2, solver=saga;, score=0.506 total time=   0.0s
# [CV 1/5] END C=10, class_weight=balanced, max_iter=300, penalty=l1, solver=liblinear;, score=0.537 total time=   0.0s
# [CV 2/5] END C=10, class_weight=balanced, max_iter=300, penalty=l1, solver=liblinear;, score=0.506 total time=   0.0s
# [CV 3/5] END C=10, class_weight=balanced, max_iter=300, penalty=l1, solver=liblinear;, score=0.562 total time=   0.0s
# [CV 4/5] END C=10, class_weight=balanced, max_iter=300, penalty=l1, solver=liblinear;, score=0.556 total time=   0.0s
# [CV 5/5] END C=10, class_weight=balanced, max_iter=300, penalty=l1, solver=liblinear;, score=0.506 total time=   0.0s
# [CV 1/5] END C=10, class_weight=balanced, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=10, class_weight=balanced, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=10, class_weight=balanced, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=10, class_weight=balanced, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=10, class_weight=balanced, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=10, class_weight=balanced, max_iter=300, penalty=l1, solver=saga;, score=0.537 total time=   0.0s
# [CV 2/5] END C=10, class_weight=balanced, max_iter=300, penalty=l1, solver=saga;, score=0.506 total time=   0.0s
# [CV 3/5] END C=10, class_weight=balanced, max_iter=300, penalty=l1, solver=saga;, score=0.562 total time=   0.0s
# [CV 4/5] END C=10, class_weight=balanced, max_iter=300, penalty=l1, solver=saga;, score=0.556 total time=   0.0s
# [CV 5/5] END C=10, class_weight=balanced, max_iter=300, penalty=l1, solver=saga;, score=0.506 total time=   0.0s
# [CV 1/5] END C=10, class_weight=balanced, max_iter=300, penalty=l2, solver=liblinear;, score=0.531 total time=   0.0s
# [CV 2/5] END C=10, class_weight=balanced, max_iter=300, penalty=l2, solver=liblinear;, score=0.506 total time=   0.0s
# [CV 3/5] END C=10, class_weight=balanced, max_iter=300, penalty=l2, solver=liblinear;, score=0.556 total time=   0.0s
# [CV 4/5] END C=10, class_weight=balanced, max_iter=300, penalty=l2, solver=liblinear;, score=0.550 total time=   0.0s
# [CV 5/5] END C=10, class_weight=balanced, max_iter=300, penalty=l2, solver=liblinear;, score=0.506 total time=   0.0s
# [CV 1/5] END C=10, class_weight=balanced, max_iter=300, penalty=l2, solver=lbfgs;, score=0.531 total time=   0.0s
# [CV 2/5] END C=10, class_weight=balanced, max_iter=300, penalty=l2, solver=lbfgs;, score=0.506 total time=   0.0s
# [CV 3/5] END C=10, class_weight=balanced, max_iter=300, penalty=l2, solver=lbfgs;, score=0.556 total time=   0.0s
# [CV 4/5] END C=10, class_weight=balanced, max_iter=300, penalty=l2, solver=lbfgs;, score=0.550 total time=   0.0s
# [CV 5/5] END C=10, class_weight=balanced, max_iter=300, penalty=l2, solver=lbfgs;, score=0.506 total time=   0.0s
# [CV 1/5] END C=10, class_weight=balanced, max_iter=300, penalty=l2, solver=saga;, score=0.531 total time=   0.0s
# [CV 2/5] END C=10, class_weight=balanced, max_iter=300, penalty=l2, solver=saga;, score=0.506 total time=   0.0s
# [CV 3/5] END C=10, class_weight=balanced, max_iter=300, penalty=l2, solver=saga;, score=0.556 total time=   0.0s
# [CV 4/5] END C=10, class_weight=balanced, max_iter=300, penalty=l2, solver=saga;, score=0.550 total time=   0.0s
# [CV 5/5] END C=10, class_weight=balanced, max_iter=300, penalty=l2, solver=saga;, score=0.506 total time=   0.0s
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'C': [0.001, 0.01, 0.1, 1, 10],
#                          'class_weight': [None, 'balanced'],
#                          'max_iter': [100, 200, 300], 'penalty': ['l1', 'l2'],
#                          'solver': ['liblinear', 'lbfgs', 'saga']},
#              scoring='accuracy', verbose=5)

# %%
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)
# Out:
# Best Hyperparameters: {'C': 0.001, 'class_weight': None, 'max_iter': 100, 'penalty': 'l1', 'solver': 'liblinear'}

# %%
model = LogisticRegression(C = 0.001, class_weight = None, max_iter = 100, penalty = 'l1', solver = 'liblinear')

# %%
model.fit(X_train,y_train)
ypred = model.predict(X_test)
print('\033[1m'+'Logistics Regression Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Logistics Regression :'+'\033[0m', accuracy_score(y_test, ypred))
print('\n')
print('\033[1m'+'Confusion matrix of Logistics Regression :'+'\033[0m \n',confusion_matrix(y_test, ypred))
print('\n')
print('\033[1m'+'classification Report of Logistics Regression'+'\033[0m \n',classification_report(y_test,ypred))
# Out:
# Logistics Regression Evaluation
#
#
# Accuracy Score of Logistics Regression : 0.755
#
#
# Confusion matrix of Logistics Regression :
#  [[151   0]
#  [ 49   0]]
#
#
# classification Report of Logistics Regression
#                precision    recall  f1-score   support
#
#            0       0.76      1.00      0.86       151
#            1       0.00      0.00      0.00        49
#
#     accuracy                           0.76       200
#    macro avg       0.38      0.50      0.43       200
# weighted avg       0.57      0.76      0.65       200

# %% [markdown]
# # Saving Best Model

# %%
import joblib
joblib.dump(model,'Insurance_claim_Fraud_Detection.pkl')
# Out:
# ['Insurance_claim_Fraud_Detection.pkl']
